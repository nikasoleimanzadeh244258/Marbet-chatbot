# %%
import fitz  # PyMuPDF
import os

# Function to extract text from all PDFs in a folder
def extract_text_from_pdfs(folder_path):
    all_text = []
    for filename in os.listdir(folder_path):
        if filename.endswith(".pdf"):  # Check if the file is a PDF
            with fitz.open(os.path.join(folder_path, filename)) as doc:
                pdf_text = ""
                for page in doc:
                    pdf_text += page.get_text()  # Extract text from each page
                all_text.append(pdf_text)  # Append extracted text from each PDF
    return all_text

# Specify folder path containing your PDFs
pdf_folder_path = r"C:\Users\Asus\Desktop\Chatbot"
pdf_texts = extract_text_from_pdfs(pdf_folder_path)

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Initialize text splitter with larger chunk size and overlap for better context capture
splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=100)

all_chunks = []
for text in pdf_texts:
    chunks = splitter.split_text(text)  # Split each PDF's text into chunks
    all_chunks.extend(chunks)  # Add the chunks to the all_chunks list

# %%
print(f"Documents passed to the model: {all_chunks}")
# Out:
# Documents passed to the model: ['ACTIVITY OVERVIEW | SALES TRIP 2024\nBelow you will find a list of all optional activities offered during the Sales trip in', 'Below you will find a list of all optional activities offered during the Sales trip in \nCanada and the USA. If you just want to find out about your selected activities, we', 'Canada and the USA. If you just want to find out about your selected activities, we \nrecommend that you check your personal agenda. There you will find all the times and', 'recommend that you check your personal agenda. There you will find all the times and \nfurther information for participants.\nSaturday, 05.10.2024 | Halifax\n1. Election program: Walking tour in Halifax', 'Saturday, 05.10.2024 | Halifax\n1. Election program: Walking tour in Halifax\nHalifax is considered the gateway to the province of Nova Scotia and one of the', 'Halifax is considered the gateway to the province of Nova Scotia and one of the \n(truly) "coolest" harbor cities in Canada. Our tour takes us along historic Hollis Street', '(truly) "coolest" harbor cities in Canada. Our tour takes us along historic Hollis Street \nwith its beautiful Gregorian houses. After a stop at the old cemetery and the', 'with its beautiful Gregorian houses. After a stop at the old cemetery and the \ngovernment building - home to the Lieutenant Governor of Nova Scotia - we', "government building - home to the Lieutenant Governor of Nova Scotia - we \ncontinue to St. Paul's Church. Enjoy the great view from Citadel Hill and stroll", "continue to St. Paul's Church. Enjoy the great view from Citadel Hill and stroll \nthrough the Public Gardens. Let yourself go at the Farmers Market, the library and \nthe waterfront.", 'through the Public Gardens. Let yourself go at the Farmers Market, the library and \nthe waterfront.\n2. Leisure time on the Scenic Eclipse', 'the waterfront.\n2. Leisure time on the Scenic Eclipse\nA perfect balance of luxury, relaxation and activity awaits you on the Scenic Eclipse.', 'A perfect balance of luxury, relaxation and activity awaits you on the Scenic Eclipse. \nThe modern fitness studio and varied sports courses ensure physical well-being. Those', 'The modern fitness studio and varied sports courses ensure physical well-being. Those \nwho prefer to improve their culinary skills can take part in gourmet cooking courses and', 'who prefer to improve their culinary skills can take part in gourmet cooking courses and \nwine tastings at the highest level. Or you can indulge in exclusive spa treatments', 'wine tastings at the highest level. Or you can indulge in exclusive spa treatments \n(self-pay basis). Immerse yourself in a world where wellness, fitness and indulgence', '(self-pay basis). Immerse yourself in a world where wellness, fitness and indulgence \nmerge into a harmonious overall experience.\nSunday, 06.10.2024 | Lunenburg', 'merge into a harmonious overall experience.\nSunday, 06.10.2024 | Lunenburg\n1. Election program: Walking tour in Lunenburg', 'Sunday, 06.10.2024 | Lunenburg\n1. Election program: Walking tour in Lunenburg\nDiscover the unique character of this coastal town, admire the colorful half-timbered', 'Discover the unique character of this coastal town, admire the colorful half-timbered \nhouses and learn more about the maritime tradition that makes Lunenburg a unique', "houses and learn more about the maritime tradition that makes Lunenburg a unique \njewel on Canada's Atlantic coast. Our tour is filled with fascinating history and", "jewel on Canada's Atlantic coast. Our tour is filled with fascinating history and \narchitecture from the 18th and 19th centuries.", 'architecture from the 18th and 19th centuries.\nCentury. The knowledgeable guides breathe new life into the places with entertaining', 'Century. The knowledgeable guides breathe new life into the places with entertaining \nanecdotes, local stories and unique recommendations. The tour ends with a stop at', 'anecdotes, local stories and u ...

# %%
from langchain.embeddings import OllamaEmbeddings
from langchain.vectorstores import FAISS

# Initialize OllamaEmbeddings (Make sure to use an up-to-date model)
embedding_model = OllamaEmbeddings(model="llama3.2")

# Generate the FAISS vector store from the chunks
vectorstore = FAISS.from_texts(all_chunks, embedding=embedding_model)

# Save the vector store locally for later use
vectorstore.save_local("marbet_vectorstore")

# %%
from langchain.chains import RetrievalQA
from langchain_ollama import ChatOllama

from langchain.prompts import ChatPromptTemplate

# Define the language model and the prompt template
llm = ChatOllama(
    base_url="http://localhost:11434",  # This is the correct base URL for your Ollama model
    model="llama3.2"
)

# Use the FAISS vector store as the retriever
retriever = vectorstore.as_retriever()

# Define the template for the chatbot response
template = """
You are a helpful assistant. Answer the following question based on the context provided. 

Here is some context about the documents:
1. Activities and excursions
2. Packing list
3. Scenic Eclipse A-Z Guide
4. Tutorials and additional documents
5. Travel Itinerary

{context}

Now, answer the user's question:
"""

# template =  """
# You are a helpful assistant. Answer the question based on the following documents:

# {context}

# Now, answer the user's question:
# """


prompt = ChatPromptTemplate.from_template(template)

# Set up the RetrievalQA chain
qa = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    chain_type_kwargs={"prompt": prompt},
    return_source_documents=True
)

# %%
# Interactive loop for asking questions
while True:
    # Ask the user for input
    question = input("I'm here to help you! What is your question? (type 'exit' to quit): ")
    
    # Exit condition
    if question.lower() == 'exit':
        break
    
    # # Get the answer using the QA system
    # result = qa.invoke({"documents": all_chunks, "query": question})
    
    # # Print the result
    # print(result["result"])

    # Retrieve documents based on the question
    retrieved_docs = retriever.invoke({"query": question}) 
    print(f"Retrieved documents: {retrieved_docs}")  # Debug: print retrieved documents

 # Ensure 'query' key is used and 'documents' are passed correctly
    prompt_to_model = prompt.format(context=" ".join([doc.page_content for doc in retrieved_docs]))  # Ensure proper context format
    print(f"Prompt being sent to the model: {prompt_to_model}")  # Debug: print the generated prompt


    # Ensure 'query' key is used and 'documents' are passed correctly
    result = qa.invoke({"documents": retrieved_docs, "query": question})
    
    # Print the result (make sure to check the model output)
    print(f"Raw output: {result}")  # Debug: print raw model output

    # Print only the result part to show the final answer
    print(f"Answer: {result['result']}")
# Out:
# Retrieved documents: [Document(id='1e9bfafe-c170-4090-9ba4-22749bb1df1a', metadata={}, page_content='Code input\nYou will receive a 4-digit code by e-mail, which you enter in the following window and confirm with [ENTER CODE].\nEnter personal data\nPlease state whether you are known under any other names (e.g. stage names) and whether you have ever held a passport or identity \ncard from another country.\nSocial media\nOnly optional to fill in.\nGE/NEXUS/SENTRI membership\nPlease select [NO].\nParents\nPlease enter the names of your parents.\nInformation about your professional career\nPlease indicate whether you currently have an employer and enter the information.\nTravel information\nPlease click [NO] when asked if you are in transit.\nIndicate your location in the USA. Please enter the data of the ship:\n1) Name: M.V. Scenic Eclipse\n2) Address: 4000 Hollywood Blvd - Apartment No. Suite 625\n3) City: Hollywood\n4) State: Florida\n5) Country code: USA (+1)\n6) Telephone number: 857-837-0373'), Document(id='f7583de0-fd5b-4bc6-a9d7-cb1c9ee74702', metadata={}, page_content='Please also check your spam folder in your mailbox.\nHowever, some applications may take several days to process. If this is the case with your application, you will receive an email \nconfirming receipt from the IRCC (Immigration, Refugees and Citizenship Canada) and another email informing you of the next \nsteps.\nRetrieve / check individual application\nOnce you have received confirmation by email, you can check the processing progress of your application using \nthe eTA status check tool.\nFor this you need:\n▪The application number beginning with the letter V; you will find this at the top of the e-mail and\n▪Details of the passport you used to apply for your eTA.\nAs soon as your eTA has been approved, you will receive a confirmation email.\nWe ask you to keep this printout in your hand luggage together with your passport for your flight, check-in \non board and at the end of your journey for the border authorities.'), Document(id='2b8a0abb-59ae-40d4-91fd-70ab8c73b02c', metadata={}, page_content='Packing list\nTravel documents and finances\n✓Passport\n✓ESTA authorization /eTA authorization\n✓Health insurance card\n✓Credit card (plus telephone number to block the card in an emergency). Note:\nDepending on the credit card, a PIN may be requested.\n✓Flight itinerary, which you received by e-mail\n✓Rail tickets, if applicable, if you have specified Rail&Fly\n✓Vaccination certificate\nClothing and shoes\n✓During the day: sporty - casual leisure wear and comfortable, sturdy\nshoes for excursions\n✓Please dress appropriately at mealtimes\n✓In the evening: smart - casual, smart but casual: with jeans or trousers,\nshirt, blouse or dress you are dressed just right.\nHighlight evening on 11.10. in New York City - Motto: Glitz & Glamor We\nask you to choose a festive and elegant gown.\nFor the gentlemen: nice evening wear (shirt, no jacket headlights) For\nthe ladies: chic & party-ready\n✓Warm sweaters and a jacket for cool temperatures\n✓Rain jacket\n✓Headgear (sun hat, cap, baseball cap or similar)'), Document(id='63920a33-d0fe-48d5-970f-1aa897afcaf2', metadata={}, page_content='E-mail confirmation\nAfter your application has been approved, you will receive an email. Please then go back to the original website \nhttps://esta.cbp.dhs.gov/ and change the language to [GERMAN] in the top right-hand corner.\nStatus\nClick on [CHECK ESTA STATUS], select [CHECK INDIVIDUAL STATUS] or [CHECK GROUP STATUS].\nIf you have not received an e-mail, you can also check the status this way.\nRetrieve individual application\nEnter your passport number and date of birth as well as your order number and click [CALL APPLICATION]. If you have \nmisplaced these, you can also enter the following data on the right:\n• Nationality\n• Date of issue of your passport\n• Validity of your passport\nYour approved ESTA\nYou will be shown your approved ESTA, which you should print out and save ...
# Prompt being sent to the model: Human:
# You are a helpful assistant. Answer the following question based on the context provided.
#
# Here is some context about the documents:
# 1. Activities and excursions
# 2. Packing list
# 3. Scenic Eclipse A-Z Guide
# 4. Tutorials and additional documents
# 5. Travel Itinerary
#
# Code input
# You will receive a 4-digit code by e-mail, which you enter in the following window and confirm with [ENTER CODE].
# Enter personal data
# Please state whether you are known under any other names (e.g. stage names) and whether you have ever held a passport or identity
# card from another country.
# Social media
# Only optional to fill in.
# GE/NEXUS/SENTRI membership
# Please select [NO].
# Parents
# Please enter the names of your parents.
# Information about your professional career
# Please indicate whether you currently have an employer and enter the information.
# Travel information
# Please click [NO] when asked if you are in transit.
# Indicate your location in the USA. Please enter the data of the ship:
# 1) Name: M.V. Scenic Eclipse
# 2) Address: 4000 Hollywood Blvd - Apartment No. Suite 625
# 3) City: Hollywood
# 4) State: Florida
# 5) Country code: USA (+1)
# 6) Telephone number: 857-837-0373 Please also check your spam folder in your mailbox.
# However, some applications may take several days to process. If this is the case with your application, you will receive an email
# confirming receipt from the IRCC (Immigration, Refugees and Citizenship Canada) and another email informing you of the next
# steps.
# Retrieve / check individual application
# Once you have received confirmation by email, you can check the processing progress of your application using
# the eTA status check tool.
# For this you need:
# ▪The application number beginning with the letter V; you will find this at the top of the e-mail and
# ▪Details of the passport you used to apply for your eTA.
# As soon as your eTA has been approved, you will receive a confirmation email.
# We ask you to keep this printout in your hand luggage together with your passport for your flight, check-in
# on board and at the end of your journey for the border authorities. Packing list
# Travel documents and finances
# ✓Passport
# ✓ESTA authorization /eTA authorization
# ✓Health insurance card
# ✓Credit card (plus telephone number to block the card in an emergency). Note:
# Depending on the credit card, a PIN may be requested.
# ✓Flight itinerary, which you received by e-mail
# ✓Rail tickets, if applicable, if you have specified Rail&Fly
# ✓Vaccination certificate
# Clothing and shoes
# ✓During the day: sporty - casual leisure wear and comfortable, sturdy
# shoes for excursions
# ✓Please dress appropriately at mealtimes
# ✓In the evening: smart - casual, smart but casual: with jeans or trousers,
# shirt, blouse or dress you are dressed just right.
# Highlight evening on 11.10. in New York City - Motto: Glitz & Glamor We
# ask you to choose a festive and elegant gown.
# For the gentlemen: nice evening wear (shirt, no jacket headlights) For
# the ladies: chic & party-ready
# ✓Warm sweaters and a jacket for cool temperatures
# ✓Rain jacket
# ✓Headgear (sun hat, cap, baseball cap or similar) E-mail confirmation
# After your application has been approved, you will receive an email. Please then go back to the original website
# https://esta.cbp.dhs.gov/ and change the language to [GERMAN] in the top right-hand corner.
# Status
# Click on [CHECK ESTA STATUS], select [CHECK INDIVIDUAL STATUS] or [CHECK GROUP STATUS].
# If you have not received an e-mail, you can also check the status this way.
# Retrieve individual application
# Enter your passport number and date of birth as well as your order number and click [CALL APPLICATION]. If you have
# misplaced these, you can also enter the following data on the right:
# • Nationality
# • Date of issue of your passport
# • Validity of your passport
# Your approved ESTA
# You will be shown your approved ESTA, which you should print out and save.
# We ask you to keep this printout in your hand luggage together with your passport for your flight, check-in
# on board and at the end of your journey for the border authorities.
#
# Now, answer the user's question:
#
# Raw output: {'documents': [Document(id='1e9bfafe-c170-4090-9ba4-22749bb1df1a', metadata={}, page_content='Code input\nYou will receive a 4-digit code by e-mail, which you enter in the following window and confirm with [ENTER CODE].\nEnter personal data\nPlease state whether you are known under any other names (e.g. stage names) and whether you have ever held a passport or identity \ncard from another country.\nSocial media\nOnly optional to fill in.\nGE/NEXUS/SENTRI membership\nPlease select [NO].\nParents\nPlease enter the names of your parents.\nInformation about your professional career\nPlease indicate whether you currently have an employer and enter the information.\nTravel information\nPlease click [NO] when asked if you are in transit.\nIndicate your location in the USA. Please enter the data of the ship:\n1) Name: M.V. Scenic Eclipse\n2) Address: 4000 Hollywood Blvd - Apartment No. Suite 625\n3) City: Hollywood\n4) State: Florida\n5) Country code: USA (+1)\n6) Telephone number: 857-837-0373'), Document(id='f7583de0-fd5b-4bc6-a9d7-cb1c9ee74702', metadata={}, page_content='Please also check your spam folder in your mailbox.\nHowever, some applications may take several days to process. If this is the case with your application, you will receive an email \nconfirming receipt from the IRCC (Immigration, Refugees and Citizenship Canada) and another email informing you of the next \nsteps.\nRetrieve / check individual application\nOnce you have received confirmation by email, you can check the processing progress of your application using \nthe eTA status check tool.\nFor this you need:\n▪The application number beginning with the letter V; you will find this at the top of the e-mail and\n▪Details of the passport you used to apply for your eTA.\nAs soon as your eTA has been approved, you will receive a confirmation email.\nWe ask you to keep this printout in your hand luggage together with your passport for your flight, check-in \non board and at the end of your journey for the border authorities.'), Document(id='2b8a0abb-59ae-40d4-91fd-70ab8c73b02c', metadata={}, page_content='Packing list\nTravel documents and finances\n✓Passport\n✓ESTA authorization /eTA authorization\n✓Health insurance card\n✓Credit card (plus telephone number to block the card in an emergency). Note:\nDepending on the credit card, a PIN may be requested.\n✓Flight itinerary, which you received by e-mail\n✓Rail tickets, if applicable, if you have specified Rail&Fly\n✓Vaccination certificate\nClothing and shoes\n✓During the day: sporty - casual leisure wear and comfortable, sturdy\nshoes for excursions\n✓Please dress appropriately at mealtimes\n✓In the evening: smart - casual, smart but casual: with jeans or trousers,\nshirt, blouse or dress you are dressed just right.\nHighlight evening on 11.10. in New York City - Motto: Glitz & Glamor We\nask you to choose a festive and elegant gown.\nFor the gentlemen: nice evening wear (shirt, no jacket headlights) For\nthe ladies: chic & party-ready\n✓Warm sweaters and a jacket for cool temperatures\n✓Rain jacket\n✓Headgear (sun hat, cap, baseball cap or similar)'), Document(id='63920a33-d0fe-48d5-970f-1aa897afcaf2', metadata={}, page_content='E-mail confirmation\nAfter your application has been approved, you will receive an email. Please then go back to the original website \nhttps://esta.cbp.dhs.gov/ and change the language to [GERMAN] in the top right-hand corner.\nStatus\nClick on [CHECK ESTA STATUS], select [CHECK INDIVIDUAL STATUS] or [CHECK GROUP STATUS].\nIf you have not received an e-mail, you can also check the status this way.\nRetrieve individual application\nEnter your passport number and date of birth as well as your order number and click [CALL APPLICATION]. If you have \nmisplaced these, you can also enter the following data on the right:\n• Nationality\n• Date of issue of your passport\n• Validity of your passport\nYour approved ESTA\nYou will be shown your approved ESTA, which you should print out and ...
# Answer: I don't see a question provided. Please provide the question you would like me to answer based on the context provided.
